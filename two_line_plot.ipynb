# %%
import matplotlib.pyplot as plt

# %%
#Line1 points
x1 = [1, 2, 3]
y1 = [2, 4, 1]
#plotting line1 in points
plt.plot(x1, y1, label = "line 1")
#plt.show()
#line 2 points
x2 = [1, 2, 3]
y2 = [4, 1, 3]
plt.plot(x2, y2, label = "line 2")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title("Two Lines On Same Graph")
plt.legend()
plt.show()

# %%
#Customization Of Plots
x = [1, 2, 3, 4, 5, 6]
y = [2, 3, 4, 5, 6, 7]
plt.plot(x, y, color = "green", linestyle = "dashed", linewidth = 3, marker = "o", markerfacecolor = "blue", markersize = 12)
plt.ylim(1, 8)
plt.xlim(1, 8)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title("customization")
plt.show()

# %%
#BAR GRAPHS
values = [5, 6, 3, 7, 2]
names = ["A", "B", "C", "D", "E"]
plt.bar(names, values, color = "yellow")
plt.show()

# %%
values = [5, 6, 3, 7, 2]
names = ["A", "B", "C", "D", "E"]
plt.barh(names, values, color = "yellowgreen")
plt.show()

# %%
#Bar Chart
import matplotlib.pyplot as plt
height = [10, 24, 36, 40, 5]
names = ["one", "two", "three", "four", "five"]
colors = ["red", "green", "blue", "yellow", "magenta"]
plt.bar(height, names, color = colors, width = 3)

plt.show()

# %%
#HISTOGRAM
args = [2, 5, 70, 40, 30, 45, 43, 40, 44, 60, 57, 90, 77]
#range = (0, 100)
bins = 10
plt.hist(args, bins, color = "blue", histtype = "bar")
plt.show()
