# %%
from statistics import StatisticsError

import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\rukhi\Downloads\BlinkIT Grocery Data.xlsx")

# %%
#Data Exploration
#View top rows
df.head()
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2016            OUT046               Tier 1
# 3                       2014            OUT013               Tier 3
# 4                       2015            OUT045               Tier 2
#
#   Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 0      Medium  Supermarket Type1         0.100014        15.10  145.4786
# ...

# %%
#View Top Rows as you desire
n = 10
df.head(n)
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
# 5          low fat           FDS52           Frozen Foods
# 6          Low Fat           NCU05     Health and Hygiene
# 7          Low Fat           NCD30              Household
# 8          Low Fat           FDW20  Fruits and Vegetables
# 9          Low Fat           FDX25                 Canned
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2016            OUT046               Tier 1
# ...

# %%
#View Bottom Rows
df.tail()
# Out:
#      Item Fat Content Item Identifier           Item Type  \
# 8518          low fat           NCT53  Health and Hygiene
# 8519          low fat           FDN09         Snack Foods
# 8520          low fat           DRE13         Soft Drinks
# 8521          Regular           FDT50               Dairy
# 8522          Regular           FDM58         Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8518                       2018            OUT027               Tier 3
# 8519                       2018            OUT027               Tier 3
# 8520                       2018            OUT027               Tier 3
# 8521                       2018            OUT027               Tier 3
# 8522                       2018            OUT027               Tier 3
#
#      Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 8518      Medium  Supermarket Type3         0.000000          NaN  164.5526
# ...

# %%
#View Bottom rows as you desire

df.tail(15)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8508          Regular           FDU57            Snack Foods
# 8509          Regular           FDU58            Snack Foods
# 8510          Regular           FDX46            Snack Foods
# 8511          Regular           FDX57            Snack Foods
# 8512          Regular           FDY33            Snack Foods
# 8513          Regular           DRY23            Soft Drinks
# 8514          low fat           FDA11           Baking Goods
# 8515          low fat           FDK38                 Canned
# 8516          low fat           FDO38                 Canned
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521          Regular           FDT50                  Dairy
# ...

# %%
#SUMMARY Statistics
#describe() -> gives you a statistical summary of your data — mainly for numeric columns by default.like count, mean, min, max, std
df.describe()
# Out:
#        Outlet Establishment Year  Item Visibility  Item Weight        Sales  \
# count                8523.000000      8523.000000  7060.000000  8523.000000
# mean                 2016.450546         0.066132    12.857645   140.992783
# std                     3.189396         0.051598     4.643456    62.275067
# min                  2011.000000         0.000000     4.555000    31.290000
# 25%                  2014.000000         0.026989     8.773750    93.826500
# 50%                  2016.000000         0.053931    12.600000   143.012800
# 75%                  2018.000000         0.094585    16.850000   185.643700
# max                  2022.000000         0.328391    21.350000   266.888400
#
#             Rating
# count  8523.000000
# mean      3.965857
# std       0.605651
# min       1.000000
# 25%       4.000000
# 50%       4.000000
# 75%       4.200000
# max       5.000000

# %%
#column names no ()
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
#Data Types
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %%
#Check For Missing Values i.e. isnull().sum()
df.isnull()
# Out:
#       Item Fat Content  Item Identifier  Item Type  Outlet Establishment Year  \
# 0                False            False      False                      False
# 1                False            False      False                      False
# 2                False            False      False                      False
# 3                False            False      False                      False
# 4                False            False      False                      False
# ...                ...              ...        ...                        ...
# 8518             False            False      False                      False
# 8519             False            False      False                      False
# 8520             False            False      False                      False
# 8521             False            False      False                      False
# 8522             False            False      False                      False
#
# ...

# %%
df.isnull().sum(

)
# Out:
# Item Fat Content                0
# Item Identifier                 0
# Item Type                       0
# Outlet Establishment Year       0
# Outlet Identifier               0
# Outlet Location Type            0
# Outlet Size                     0
# Outlet Type                     0
# Item Visibility                 0
# Item Weight                  1463
# Sales                           0
# Rating                          0
# dtype: int64

# %%
#Data Selection
#1.select a column name
df['Item Fat Content']
# Out:
# 0       Regular
# 1       Low Fat
# 2       Regular
# 3       Regular
# 4       Low Fat
#          ...
# 8518    low fat
# 8519    low fat
# 8520    low fat
# 8521    Regular
# 8522    Regular
# Name: Item Fat Content, Length: 8523, dtype: object

# %%
#2.Select Multiple Columnns for multiple columns use [[]]
df[['Item Fat Content', 'Outlet Identifier']]
# Out:
#      Item Fat Content Outlet Identifier
# 0             Regular            OUT049
# 1             Low Fat            OUT018
# 2             Regular            OUT046
# 3             Regular            OUT013
# 4             Low Fat            OUT045
# ...               ...               ...
# 8518          low fat            OUT027
# 8519          low fat            OUT027
# 8520          low fat            OUT027
# 8521          Regular            OUT027
# 8522          Regular            OUT027
#
# [8523 rows x 2 columns]

# %%
#3.select rows by index
df.iloc[10:35]
# Out:
#    Item Fat Content Item Identifier              Item Type  \
# 10          Low Fat           FDX21            Snack Foods
# 11          Low Fat           NCU41     Health and Hygiene
# 12          Low Fat           FDL20  Fruits and Vegetables
# 13          Low Fat           NCR54              Household
# 14          Low Fat           FDH19                   Meat
# 15          Regular           FDB57  Fruits and Vegetables
# 16          Low Fat           FDO23                 Breads
# 17          Low Fat           NCB07              Household
# 18          Low Fat           FDJ56  Fruits and Vegetables
# 19          Low Fat           DRN47            Hard Drinks
# 20          Regular           FDZ07  Fruits and Vegetables
# 21          Low Fat           NCK31                 Others
# 22          Low Fat           FDJ41           Frozen Foods
# 23          Low Fat           DRI51                  Dairy
# 24          Regular           FDC40                  Dairy
# ...

# %%
#2.Select rows by condition:
df[df['Sales'] > 10]
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 1             Low Fat           NCB42     Health and Hygiene
# 2             Regular           FDR28           Frozen Foods
# 3             Regular           FDL50                 Canned
# 4             Low Fat           DRI25            Soft Drinks
# ...               ...             ...                    ...
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521          Regular           FDT50                  Dairy
# 8522          Regular           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# 1                          2022            OUT018               Tier 3
# ...

# %%
#Data Manipulation
#1.Add a new Column
df['new_column'] = df['Outlet Size'] + df['Outlet Identifier']
print(df['new_column'])
# Out:
# 0       MediumOUT049
# 1       MediumOUT018
# 2        SmallOUT046
# 3         HighOUT013
# 4        SmallOUT045
#             ...
# 8518    MediumOUT027
# 8519    MediumOUT027
# 8520    MediumOUT027
# 8521    MediumOUT027
# 8522    MediumOUT027
# Name: new_column, Length: 8523, dtype: object

# %%
#2.Drop Column
df = df.drop(['Item Weight', 'Sales'], axis=1)
print(df)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 1             Low Fat           NCB42     Health and Hygiene
# 2             Regular           FDR28           Frozen Foods
# 3             Regular           FDL50                 Canned
# 4             Low Fat           DRI25            Soft Drinks
# ...               ...             ...                    ...
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521          Regular           FDT50                  Dairy
# 8522          Regular           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# 1                          2022            OUT018               Tier 3
# ...

# %%
# 3.Rename Column
df.rename(columns={'Outlet Establishment Year': 'Item_Weight1'}, inplace=True)
print(df)
# Out:
#      Item Fat Content Item Identifier              Item Type  Item_Weight1  \
# 0             Regular           FDX32  Fruits and Vegetables          2012
# 1             Low Fat           NCB42     Health and Hygiene          2022
# 2             Regular           FDR28           Frozen Foods          2016
# 3             Regular           FDL50                 Canned          2014
# 4             Low Fat           DRI25            Soft Drinks          2015
# ...               ...             ...                    ...           ...
# 8518          low fat           NCT53     Health and Hygiene          2018
# 8519          low fat           FDN09            Snack Foods          2018
# 8520          low fat           DRE13            Soft Drinks          2018
# 8521          Regular           FDT50                  Dairy          2018
# 8522          Regular           FDM58            Snack Foods          2018
#
# ...

# %%
#4.Replace values
df['Item Fat Content'] = df['Item Fat Content'].replace('Low Fat','Low_with_Fat')
print(df)
# Out:
#      Item Fat Content Item Identifier              Item Type  Item_Weight1  \
# 0             Regular           FDX32  Fruits and Vegetables          2012
# 1        Low_with_Fat           NCB42     Health and Hygiene          2022
# 2             Regular           FDR28           Frozen Foods          2016
# 3             Regular           FDL50                 Canned          2014
# 4        Low_with_Fat           DRI25            Soft Drinks          2015
# ...               ...             ...                    ...           ...
# 8518          low fat           NCT53     Health and Hygiene          2018
# 8519          low fat           FDN09            Snack Foods          2018
# 8520          low fat           DRE13            Soft Drinks          2018
# 8521          Regular           FDT50                  Dairy          2018
# 8522          Regular           FDM58            Snack Foods          2018
#
# ...

# %%
#GROUPING AND AGGREGATION
#1.Group Data
grouped = df.groupby('Outlet Size')
print(df)
# Out:
#      Item Fat Content Item Identifier              Item Type  Item_Weight1  \
# 0             Regular           FDX32  Fruits and Vegetables          2012
# 1        Low_with_Fat           NCB42     Health and Hygiene          2022
# 2             Regular           FDR28           Frozen Foods          2016
# 3             Regular           FDL50                 Canned          2014
# 4        Low_with_Fat           DRI25            Soft Drinks          2015
# ...               ...             ...                    ...           ...
# 8518          low fat           NCT53     Health and Hygiene          2018
# 8519          low fat           FDN09            Snack Foods          2018
# 8520          low fat           DRE13            Soft Drinks          2018
# 8521          Regular           FDT50                  Dairy          2018
# 8522          Regular           FDM58            Snack Foods          2018
#
# ...

# %%
#SORTING
#1.Sort by multiple column
df.sort_values('Sales', ascending=True)
# Out:
#      Item Fat Content Item Identifier           Item Type  Item_Weight1  \
# 5872     Low_with_Fat           DRK12         Soft Drinks          2018
# 7880     Low_with_Fat           DRK12         Soft Drinks          2014
# 8136     Low_with_Fat           DRK12         Soft Drinks          2022
# 8300     Low_with_Fat           FDG40        Frozen Foods          2018
# 7753     Low_with_Fat           FDX59              Breads          2014
# ...               ...             ...                 ...           ...
# 3563     Low_with_Fat           NCS29  Health and Hygiene          2017
# 1775     Low_with_Fat           NCS29  Health and Hygiene          2014
# 559      Low_with_Fat           FDK51               Dairy          2011
# 3398          Regular           FDR25              Canned          2016
# 183      Low_with_Fat           FDS13              Canned          2020
#
#      Outlet Identifier Outlet Location Type Outlet Size        Outlet Type  \
# ...

# %%
#2.Sort with multiple columns
df.sort_values(['Sales', 'Outlet Size'], ascending=[True, False])
# Out:
#      Item Fat Content Item Identifier           Item Type  Item_Weight1  \
# 5872     Low_with_Fat           DRK12         Soft Drinks          2018
# 7880     Low_with_Fat           DRK12         Soft Drinks          2014
# 8136     Low_with_Fat           DRK12         Soft Drinks          2022
# 8300     Low_with_Fat           FDG40        Frozen Foods          2018
# 7753     Low_with_Fat           FDX59              Breads          2014
# ...               ...             ...                 ...           ...
# 5419     Low_with_Fat           FDS13              Canned          2018
# 559      Low_with_Fat           FDK51               Dairy          2011
# 1775     Low_with_Fat           NCS29  Health and Hygiene          2014
# 183      Low_with_Fat           FDS13              Canned          2020
# 3398          Regular           FDR25              Canned          2016
#
#      Outlet Identifier Outlet Location Type Outlet Size        Outlet Type  \
# ...

# %%
#Missing Data Handling
#1.fill missing values
df.fillna({'Item Identifier': 'nan'}, inplace=True)
print(df)
# Out:
#      Item Fat Content Item Identifier              Item Type  Item_Weight1  \
# 0             Regular           FDX32  Fruits and Vegetables          2012
# 1        Low_with_Fat           NCB42     Health and Hygiene          2022
# 2             Regular           FDR28           Frozen Foods          2016
# 3             Regular           FDL50                 Canned          2014
# 4        Low_with_Fat           DRI25            Soft Drinks          2015
# ...               ...             ...                    ...           ...
# 8518          low fat           NCT53     Health and Hygiene          2018
# 8519          low fat           FDN09            Snack Foods          2018
# 8520          low fat           DRE13            Soft Drinks          2018
# 8521          Regular           FDT50                  Dairy          2018
# 8522          Regular           FDM58            Snack Foods          2018
#
# ...

# %%
#Drop rows with missing values
df.dropna(inplace = True)
print(df)
# Out:
#      Item Fat Content Item Identifier              Item Type  Item_Weight1  \
# 0             Regular           FDX32  Fruits and Vegetables          2012
# 1        Low_with_Fat           NCB42     Health and Hygiene          2022
# 2             Regular           FDR28           Frozen Foods          2016
# 3             Regular           FDL50                 Canned          2014
# 4        Low_with_Fat           DRI25            Soft Drinks          2015
# ...               ...             ...                    ...           ...
# 8241          Regular           FDH26                 Canned          2022
# 8242          Regular           FDG56  Fruits and Vegetables          2022
# 8243          Regular           FDM15                   Meat          2022
# 8244          Regular           FDX57            Snack Foods          2022
# 8245          Regular           FDD10            Snack Foods          2022
#
# ...

# %%
#MERGING DATAFRAMES
#1.CONCATENATE DF
#import pandas as pd
#import DataFrame as df
#pd.concat([['Item Fat Content', 'Item Identifier']], axis = 0)
df = pd.read_excel(r"C:\Users\rukhi\Downloads\BlinkIT Grocery Data.xlsx")

pd.concat([df['Item Fat Content'], df['Item Identifier']], axis = 1)
# Out:
#      Item Fat Content Item Identifier
# 0             Regular           FDX32
# 1             Low Fat           NCB42
# 2             Regular           FDR28
# 3             Regular           FDL50
# 4             Low Fat           DRI25
# ...               ...             ...
# 8518          low fat           NCT53
# 8519          low fat           FDN09
# 8520          low fat           DRE13
# 8521          Regular           FDT50
# 8522          Regular           FDM58
#
# [8523 rows x 2 columns]

# %%
#2.merge dataframes
df = pd.read_excel(r"C:\Users\rukhi\Downloads\BlinkIT Grocery Data.xlsx")
#pd.merge('Outlet Establishment Year', 'Item Identifier', on ='Outlet Identifier')
merged = pd.merge(
    df[['Outlet Identifier', 'Outlet Establishment Year']],  # instead of string
    df[['Outlet Identifier', 'Item Identifier']],           # instead of string
    on='Outlet Identifier'
)
print(merged)
# Out:
#         Outlet Identifier  Outlet Establishment Year Item Identifier
# 0                  OUT049                       2012           FDX32
# 1                  OUT049                       2012           NCB07
# 2                  OUT049                       2012           FDL25
# 3                  OUT049                       2012           FDB09
# 4                  OUT049                       2012           FDT34
# ...                   ...                        ...             ...
# 7506054            OUT027                       2018           NCT53
# 7506055            OUT027                       2018           FDN09
# 7506056            OUT027                       2018           DRE13
# 7506057            OUT027                       2018           FDT50
# 7506058            OUT027                       2018           FDM58
#
# [7506059 rows x 3 columns]

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\rukhi\Downloads\BlinkIT Grocery Data.xlsx")
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
#3.Join Data Frames
import pandas as pd
df = pd.read_excel(r"C:\Users\rukhi\Downloads\BlinkIT Grocery Data.xlsx")
df['Outlet Size'].join('Outlet Type')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_700\1755315679.py in ?()
#       1 #3.Join Data Frames
#       2 import pandas as pd
#       3 df = pd.read_excel(r"C:\Users\rukhi\Downloads\BlinkIT Grocery Data.xlsx")
# ----> 4 df['Outlet Size'].join('Outlet Type')
#
# ~\PyCharmMiscProject\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'join'

# %%
#PIVOT TABLES
#1.Create Pivot Table
df.pivot_table(values = 'Item Fat Content', index = 'Item Identifier', columns = 'Outlet Establishment Year', aggfunc = 'count')
# Out:
# Outlet Establishment Year  2011  2012  2014  2015  2016  2017  2018  2020  \
# Item Identifier
# DRA12                       1.0   NaN   1.0   1.0   NaN   1.0   NaN   1.0
# DRA24                       1.0   1.0   1.0   NaN   NaN   1.0   2.0   1.0
# DRA59                       1.0   1.0   1.0   NaN   1.0   NaN   2.0   1.0
# DRB01                       NaN   1.0   1.0   NaN   NaN   NaN   1.0   NaN
# DRB13                       1.0   1.0   1.0   NaN   NaN   1.0   NaN   1.0
# ...                         ...   ...   ...   ...   ...   ...   ...   ...
# NCZ30                       1.0   1.0   1.0   1.0   NaN   1.0   1.0   1.0
# NCZ41                       NaN   NaN   1.0   1.0   NaN   1.0   NaN   1.0
# NCZ42                       1.0   1.0   1.0   NaN   NaN   1.0   NaN   1.0
# NCZ53                       1.0   1.0   1.0   NaN   NaN   NaN   1.0   NaN
# NCZ54                       1.0   1.0   NaN   1.0   1.0   NaN   2.0   NaN
#
# Outlet Establishment Year  2022
# Item Identifier
# ...

# %%
#APPLY FUNCTIONS
#1.APPLY CUSTOM FUNCTIONS
df['Item Fat Content'].apply(lambda x: x * 2)
# Out:
# 0       RegularRegular
# 1       Low FatLow Fat
# 2       RegularRegular
# 3       RegularRegular
# 4       Low FatLow Fat
#              ...
# 8518    low fatlow fat
# 8519    low fatlow fat
# 8520    low fatlow fat
# 8521    RegularRegular
# 8522    RegularRegular
# Name: Item Fat Content, Length: 8523, dtype: object

# %%
#2.Apply Row wise or column wise
df.apply(lambda row: row['Item Identifier'] + row['Outlet Identifier'], axis = 1)
# Out:
# 0       FDX32OUT049
# 1       NCB42OUT018
# 2       FDR28OUT046
# 3       FDL50OUT013
# 4       DRI25OUT045
#            ...
# 8518    NCT53OUT027
# 8519    FDN09OUT027
# 8520    DRE13OUT027
# 8521    FDT50OUT027
# 8522    FDM58OUT027
# Length: 8523, dtype: object

# %%
#TIME SERIES
#1.Convert Column to datetime
df['Outlet Establishment Year'] = pd.to_datetime(df['Outlet Establishment Year'])
print(df['Outlet Establishment Year'])
# Out:
# 0      1970-01-01 00:00:00.000002012
# 1      1970-01-01 00:00:00.000002022
# 2      1970-01-01 00:00:00.000002016
# 3      1970-01-01 00:00:00.000002014
# 4      1970-01-01 00:00:00.000002015
#                     ...
# 8518   1970-01-01 00:00:00.000002018
# 8519   1970-01-01 00:00:00.000002018
# 8520   1970-01-01 00:00:00.000002018
# 8521   1970-01-01 00:00:00.000002018
# 8522   1970-01-01 00:00:00.000002018
# Name: Outlet Establishment Year, Length: 8523, dtype: datetime64[ns]

# %%
#2.Extract Specific date parts
df['Year'] = df['Outlet Establishment Year'].dt.year
print(df['Year'])
# Out:
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
#         ...
# 8518    1970
# 8519    1970
# 8520    1970
# 8521    1970
# 8522    1970
# Name: Year, Length: 8523, dtype: int32

# %%
#VISUALISATION WITH PANDAS
#1.LINE PLOT
df.plot(x='Outlet Establishment Year', y = 'Sales', kind = 'bar')
# Out:
# <Axes: xlabel='Outlet Establishment Year'>
